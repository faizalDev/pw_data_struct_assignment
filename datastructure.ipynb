# %% [markdown]
# 1. Write a code to create a string with your name and print it?

# %%
my_name = "Faizal"

print(my_name)
# Out:
# Faizal

# %% [markdown]
# 2.Write a code to find the length of the string "Hello World"

# %%
str1 = "Hello World"
print(len(str1))
# Out:
# 11

# %% [markdown]
# 3. Write a code to slice the first 3 characters from the string "Python Programming"

# %%
str2 = "Python Programming"

print(str2[:3])
# Out:
# Pyt

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase

# %%
str3 = "hello"

print(str3.upper())
# Out:
# HELLO

# %% [markdown]
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple"

# %%
str4 = "I like apple"

str4_new = str4.replace("apple", "orange")
print(str4_new)
# Out:
# I like orange

# %% [markdown]
# 6. Write a code to create a list with numbers 1 to 5 and print it

# %%
list1 = []

for i in range(1,6):
  list1.append(i)

print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4]

# %%
list2 = [1,2,3,4]

list2.append(10)

print(list2)
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]

# %%
list3 = [1, 2, 3, 4, 5]
list3.remove(3)
print(list3)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']

# %%
list4 = ['a', 'b', 'c', 'd']

print(list4[1])
# Out:
# b

# %% [markdown]
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
list6 = [10, 20, 30, 40, 50]

list6[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.

# %%
tuple1 = (100, 200, 300)

print(tuple1)
# Out:
# (100, 200, 300)

# %% [markdown]
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

# %%
tuple2 =  ('red', 'green', 'blue', 'yellow')

print(tuple2[-2])
# Out:
# blue

# %% [markdown]
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).

# %%
tuple3 = (10, 20, 5, 15)

min(tuple3)
# Out:
# 5

# %% [markdown]
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
tuple4 = ('dog', 'cat', 'rabbit')
tuple4.index("cat")
# Out:
# 1

# %% [markdown]
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

# %%
fruits = ("apple", "orange", "kiwi")

if "kiwi" in fruits:
  print("Kiwi Available")
else:
  print("Not Found")
# Out:
# Kiwi Available

# %% [markdown]
# 16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

# %%
alphabet = {'a', 'b', 'c'}

print(alphabet)
# Out:
# {'a', 'b', 'c'}

# %% [markdown]
# 17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

# %%
set1 = {1,2,3,4,5}

set1.clear()
print(set1)
# Out:
# set()

# %% [markdown]
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

# %%
set2 = {1,2,3,4}
set2.remove(4)
print(set2)
# Out:
# {1, 2, 3}

# %% [markdown]
# 19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

# %%
set3 = {1,2,3}
set4 = {3,4,5}

union_set = set3.union(set4)
print(union_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

# %%
set5 = {1,2,3}
set6 = {2,3,4}

intersection_set = set5.intersection(set6)
print(intersection_set)
# Out:
# {2, 3}

# %% [markdown]
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

# %%
dict1 = {
    "name":"Faizal",
    "age": 20,
    "city": "delhi"
}

print(dict1)
# Out:
# {'name': 'Faizal', 'age': 20, 'city': 'delhi'}

# %% [markdown]
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

# %%
dict2 = {
    "name": "John",
    "age": 25
}

dict2["country"]= "USA"

print(dict2)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %% [markdown]
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

# %%
dict3 =  {'name': 'Alice', 'age': 30}
dict3.get("name")
# Out:
# 'Alice'

# %% [markdown]
# 24. Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

# %%
dict4 = {'name': 'Bob', 'age': 22, 'city': 'New York'}

dict4.pop("age")

print(dict4)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# 25. Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

# %%
dict5 = {'name': 'Alice', 'city': 'Paris'}

if "city" in dict5:
  print("Found")
else:
  print("Not Found")
# Out:
# Found

# %% [markdown]
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.

# %%
list_new = ["apple", 10, 3.5, 3+2j]
print(list_new)

tuple_new = ("apple", 10, 3.5, 3+2j)
print(tuple_new)

dict_new = {
    "name": "Faizal",
    "age": 25,
    "blood": 'A'

}

print(dict_new)
# Out:
# ['apple', 10, 3.5, (3+2j)]
# ('apple', 10, 3.5, (3+2j))
# {'name': 'Faizal', 'age': 25, 'blood': 'A'}

# %% [markdown]
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the
# result.(replaced)

# %%
import random
list_random = []

for i in range(5):
  list_random.append(random.randint(1,100))

list_random.sort()

print(list_random)
# Out:
# [3, 55, 59, 83, 89]

# %% [markdown]
# 28. Write a code to create a list with strings and print the element at the third index.

# %%
list_str = ["Apple", "Banana", "Pomegrenate", "Avocado"]

print(list_str[3])
# Out:
# Avocado

# %% [markdown]
# 29. Write a code to combine two dictionaries into one and print the result.

# %%
dict_d1 = {
    "name": "Faiza",
    "age": 23
}

dict_d2 = {
    "blood": "A",
    "class": 10
}

dict_d1.update(dict_d2)

print(dict_d1)
# Out:
# {'name': 'Faiza', 'age': 23, 'blood': 'A', 'class': 10}

# %% [markdown]
# 30. Write a code to convert a list of strings into a set.

# %%
list_str1 = ["Apple", "Banana", "Pomegrenate", "Avocado", "Apple"]

set_str = set(list_str1)
print(set_str)
# Out:
# {'Banana', 'Avocado', 'Pomegrenate', 'Apple'}
